# %% [markdown]
# # Step 3: Robust Error Handling (Resilience)
#
# This notebook demonstrates how to reuse the agent module from the src package and test resilient API error handling.
#
# Not necessary to add below always - this is just to show the reusable folder's path-
#
# import sys
# from pathlib import Path
#
# project_root = Path.cwd().resolve()
# src_path = project_root.parent / 'src'
# if str(src_path) not in sys.path:
#     sys.path.insert(0, str(src_path))

# %%
from agent_core import mock_api_call

mock_api_call(payload={'data': 'test'}, simulate_missing_key=True)
mock_api_call(payload={'data': 'test'}, simulate_timeout=True)
# Out:
# --- INITIATING API CALL ---
# [CRITICAL ERROR] LLM output parsing failed. Missing expected key: 'usage_metrics'
# API transaction finalized (Connection Closed).
#
# --- INITIATING API CALL ---
# [NETWORK ERROR] The LLM API endpoint took too long to respond. Switching to backup endpoint...
# API transaction finalized (Connection Closed).
# False
