# %% [markdown]
# # AI Foundations Lab Notebook
#
# This starter notebook demonstrates importing from `src` using the workspace `PYTHONPATH`.

# %%
from team import TeamMember, build_welcome_context

members = [
    TeamMember("Alice", "admin"),
    TeamMember("Charlie", "editor"),
]

print(build_welcome_context(members))
# Out:
# 1. Alice
# 2. Charlie
